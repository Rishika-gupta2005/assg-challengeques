# %%
def mixs(num):
    try:
        ele = int(num)
        return (0, ele, '')
    except ValueError:
        return (1, num, '')

L = ["ram",1,"shayam",2,"aman",3]
print(L)
L.sort(key=mixs)
print(L)
# Out:
# ['ram', 1, 'shayam', 2, 'aman', 3]
# [1, 2, 3, 'aman', 'ram', 'shayam']
